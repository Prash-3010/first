# %%
# df.to_csv("clean_laptop_data_csv")

# %%
import pandas as pd

# %%
df=pd.read_csv("laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 19 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False            False           False            False   False
# 1    False            False           False            False   False
# 2    False            False           False            False   False
# 3    False            False           False            False   False
# 4    False            False           False            False   False
# ..     ...              ...             ...              ...     ...
# 818  False            False           False            False   False
# 819  False            False           False            False   False
# 820  False            False           False            False   False
# 821  False            False           False            False   False
# 822  False            False           False            False   False
#
#      ram_type    ssd    hdd     os  os_bit  graphic_card_gb  weight  warranty  \
# 0       False  False  False  False   False            False   False     False
# 1       False  False  False  False   False            False   False     False
# 2       False  False  False  False   False            False   False     False
# 3       False  False  False  False   False            False   False     False
# 4       False  False  False  False   False            False   False     False
# ..        ...    ...    ...    ...     ...              ...     ...       ...
# 818     False  False  False  False   False            False   False     False
# 819     False  False  False  False   False            False   False     False
# 820     False  False  False  False   False            False   False     False
# 821     False  False  False  False   False            False   False     False
# 822     False  False  False  False   False            False   False     False
#
#      Touchscreen  msoffice  Price  rating  Number of Ratings  \
# 0          False     False  False   False              False
# 1          False     False  False   False              False
# 2          False     False  False   False              False
# 3          False     False  False   False              False
# 4          False     False  False   False              False
# ..           ...       ...    ...     ...                ...
# 818        False     False  False   False              False
# 819        False     False  False   False              False
# 820        False     False  False   False              False
# 821        False     False  False   False              False
# 822        False     False  False   False              False
#
#      Number of Reviews
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ..                 ...
# 818              False
# 819              False
# 820              False
# 821              False
# 822              False
#
# [802 rows x 19 columns]

# %%
df.dropna()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [802 rows x 19 columns]

# %%
df.drop(['os','os_bit','weight','msoffice','rating','Number of Ratings','Number of Reviews'],axis=1,inplace=True)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd graphic_card_gb     warranty Touchscreen   Price
# 0       0 GB  1024 GB            0 GB  No warranty          No   34649
# 1       0 GB  1024 GB            0 GB  No warranty          No   38999
# 2       0 GB  1024 GB            0 GB  No warranty          No   39999
# 3     512 GB     0 GB            2 GB  No warranty          No   69990
# 4       0 GB   512 GB            0 GB  No warranty          No   26990
# ..       ...      ...             ...          ...         ...     ...
# 818  1024 GB     0 GB            0 GB       1 year          No  135990
# 819  1024 GB     0 GB            0 GB       1 year          No  144990
# 820  1024 GB     0 GB            4 GB       1 year          No  149990
# 821  1024 GB     0 GB            4 GB       1 year          No  142990
# 822   512 GB     0 GB            0 GB  No warranty          No   57490
#
# [802 rows x 12 columns]

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
brand_dict={'ASUS':1, 'Lenovo':2, 'acer':3, 'Avita':4, 'HP':5, 'DELL':6, 'MSI':7, 'APPLE':8}

# %%
df['brand']=df['brand'].map(brand_dict)

# %%
df
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0        1           Intel        Core i3            10th   4 GB     DDR4
# 1        2           Intel        Core i3            10th   4 GB     DDR4
# 2        2           Intel        Core i3            10th   4 GB     DDR4
# 3        1           Intel        Core i5            10th   8 GB     DDR4
# 4        1           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...             ...            ...             ...    ...      ...
# 818      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822      2             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd graphic_card_gb     warranty Touchscreen   Price
# 0       0 GB  1024 GB            0 GB  No warranty          No   34649
# 1       0 GB  1024 GB            0 GB  No warranty          No   38999
# 2       0 GB  1024 GB            0 GB  No warranty          No   39999
# 3     512 GB     0 GB            2 GB  No warranty          No   69990
# 4       0 GB   512 GB            0 GB  No warranty          No   26990
# ..       ...      ...             ...          ...         ...     ...
# 818  1024 GB     0 GB            0 GB       1 year          No  135990
# 819  1024 GB     0 GB            0 GB       1 year          No  144990
# 820  1024 GB     0 GB            4 GB       1 year          No  149990
# 821  1024 GB     0 GB            4 GB       1 year          No  142990
# 822   512 GB     0 GB            0 GB  No warranty          No   57490
#
# [802 rows x 12 columns]

# %%
df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
proc_brand_dict={'Intel':1, 'AMD':2, 'M1':3}

# %%
df['processor_brand']=df['processor_brand'].map(proc_brand_dict)

# %%
df
# Out:
#      brand  processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0        1                1        Core i3            10th   4 GB     DDR4
# 1        2                1        Core i3            10th   4 GB     DDR4
# 2        2                1        Core i3            10th   4 GB     DDR4
# 3        1                1        Core i5            10th   8 GB     DDR4
# 4        1                1   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...              ...            ...             ...    ...      ...
# 818      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 819      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 820      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 821      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 822      2                2        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd graphic_card_gb     warranty Touchscreen   Price
# 0       0 GB  1024 GB            0 GB  No warranty          No   34649
# 1       0 GB  1024 GB            0 GB  No warranty          No   38999
# 2       0 GB  1024 GB            0 GB  No warranty          No   39999
# 3     512 GB     0 GB            2 GB  No warranty          No   69990
# 4       0 GB   512 GB            0 GB  No warranty          No   26990
# ..       ...      ...             ...          ...         ...     ...
# 818  1024 GB     0 GB            0 GB       1 year          No  135990
# 819  1024 GB     0 GB            0 GB       1 year          No  144990
# 820  1024 GB     0 GB            4 GB       1 year          No  149990
# 821  1024 GB     0 GB            4 GB       1 year          No  142990
# 822   512 GB     0 GB            0 GB  No warranty          No   57490
#
# [802 rows x 12 columns]

# %%
df['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
proc_name_dict={'Core i3':1, 'Core i5':2, 'Celeron Dual':3, 'Ryzen 5':4, 'Core i7':5,
       'Core i9':6, 'M1':7, 'Pentium Quad':8, 'Ryzen 3':9, 'Ryzen 7':10, 'Ryzen 9':11}

# %%
df['processor_name']=df['processor_name'].map(proc_name_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name processor_gnrtn ram_gb ram_type  \
# 0        1                1               1            10th   4 GB     DDR4
# 1        2                1               1            10th   4 GB     DDR4
# 2        2                1               1            10th   4 GB     DDR4
# 3        1                1               2            10th   8 GB     DDR4
# 4        1                1               3   Not Available   4 GB     DDR4
# ..     ...              ...             ...             ...    ...      ...
# 818      1                2              11   Not Available   4 GB     DDR4
# 819      1                2              11   Not Available   4 GB     DDR4
# 820      1                2              11   Not Available   4 GB     DDR4
# 821      1                2              11   Not Available   4 GB     DDR4
# 822      2                2               4            10th   8 GB     DDR4
#
#          ssd      hdd graphic_card_gb     warranty Touchscreen   Price
# 0       0 GB  1024 GB            0 GB  No warranty          No   34649
# 1       0 GB  1024 GB            0 GB  No warranty          No   38999
# 2       0 GB  1024 GB            0 GB  No warranty          No   39999
# 3     512 GB     0 GB            2 GB  No warranty          No   69990
# 4       0 GB   512 GB            0 GB  No warranty          No   26990
# ..       ...      ...             ...          ...         ...     ...
# 818  1024 GB     0 GB            0 GB       1 year          No  135990
# 819  1024 GB     0 GB            0 GB       1 year          No  144990
# 820  1024 GB     0 GB            4 GB       1 year          No  149990
# 821  1024 GB     0 GB            4 GB       1 year          No  142990
# 822   512 GB     0 GB            0 GB  No warranty          No   57490
#
# [802 rows x 12 columns]

# %%
df['processor_gnrtn'].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
proc_gen_dict={'10th':1, 'Not Available':2, '11th':3, '7th':4, '8th':5, '9th':6, '4th':7,
       '12th':8}

# %%
df['processor_gnrtn']=df['processor_gnrtn'].map(proc_gen_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn ram_gb ram_type  \
# 0        1                1               1                1   4 GB     DDR4
# 1        2                1               1                1   4 GB     DDR4
# 2        2                1               1                1   4 GB     DDR4
# 3        1                1               2                1   8 GB     DDR4
# 4        1                1               3                2   4 GB     DDR4
# ..     ...              ...             ...              ...    ...      ...
# 818      1                2              11                2   4 GB     DDR4
# 819      1                2              11                2   4 GB     DDR4
# 820      1                2              11                2   4 GB     DDR4
# 821      1                2              11                2   4 GB     DDR4
# 822      2                2               4                1   8 GB     DDR4
#
#          ssd      hdd graphic_card_gb     warranty Touchscreen   Price
# 0       0 GB  1024 GB            0 GB  No warranty          No   34649
# 1       0 GB  1024 GB            0 GB  No warranty          No   38999
# 2       0 GB  1024 GB            0 GB  No warranty          No   39999
# 3     512 GB     0 GB            2 GB  No warranty          No   69990
# 4       0 GB   512 GB            0 GB  No warranty          No   26990
# ..       ...      ...             ...          ...         ...     ...
# 818  1024 GB     0 GB            0 GB       1 year          No  135990
# 819  1024 GB     0 GB            0 GB       1 year          No  144990
# 820  1024 GB     0 GB            4 GB       1 year          No  149990
# 821  1024 GB     0 GB            4 GB       1 year          No  142990
# 822   512 GB     0 GB            0 GB  No warranty          No   57490
#
# [802 rows x 12 columns]

# %%
df.dtypes
# Out:
# brand               int64
# processor_brand     int64
# processor_name      int64
# processor_gnrtn     int64
# ram_gb             object
# ram_type           object
# ssd                object
# hdd                object
# graphic_card_gb    object
# warranty           object
# Touchscreen        object
# Price               int64
# dtype: object

# %%
df['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
ram_gb_dict={'4 GB':4, '8 GB':8, '16 GB':16, '32 GB':32}

# %%
df['ram_gb']=df['ram_gb'].map(ram_gb_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb ram_type  \
# 0        1                1               1                1       4     DDR4
# 1        2                1               1                1       4     DDR4
# 2        2                1               1                1       4     DDR4
# 3        1                1               2                1       8     DDR4
# 4        1                1               3                2       4     DDR4
# ..     ...              ...             ...              ...     ...      ...
# 818      1                2              11                2       4     DDR4
# 819      1                2              11                2       4     DDR4
# 820      1                2              11                2       4     DDR4
# 821      1                2              11                2       4     DDR4
# 822      2                2               4                1       8     DDR4
#
#          ssd      hdd graphic_card_gb     warranty Touchscreen   Price
# 0       0 GB  1024 GB            0 GB  No warranty          No   34649
# 1       0 GB  1024 GB            0 GB  No warranty          No   38999
# 2       0 GB  1024 GB            0 GB  No warranty          No   39999
# 3     512 GB     0 GB            2 GB  No warranty          No   69990
# 4       0 GB   512 GB            0 GB  No warranty          No   26990
# ..       ...      ...             ...          ...         ...     ...
# 818  1024 GB     0 GB            0 GB       1 year          No  135990
# 819  1024 GB     0 GB            0 GB       1 year          No  144990
# 820  1024 GB     0 GB            4 GB       1 year          No  149990
# 821  1024 GB     0 GB            4 GB       1 year          No  142990
# 822   512 GB     0 GB            0 GB  No warranty          No   57490
#
# [802 rows x 12 columns]

# %%
df['ram_type'].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
ram_type_dict={'DDR4':1, 'LPDDR4':2, 'LPDDR4X':3, 'DDR5':4, 'DDR3':5, 'LPDDR3':6}

# %%
df['ram_type']=df['ram_type'].map(ram_type_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type      ssd      hdd graphic_card_gb     warranty Touchscreen  \
# 0           1     0 GB  1024 GB            0 GB  No warranty          No
# 1           1     0 GB  1024 GB            0 GB  No warranty          No
# 2           1     0 GB  1024 GB            0 GB  No warranty          No
# 3           1   512 GB     0 GB            2 GB  No warranty          No
# 4           1     0 GB   512 GB            0 GB  No warranty          No
# ..        ...      ...      ...             ...          ...         ...
# 818         1  1024 GB     0 GB            0 GB       1 year          No
# 819         1  1024 GB     0 GB            0 GB       1 year          No
# 820         1  1024 GB     0 GB            4 GB       1 year          No
# 821         1  1024 GB     0 GB            4 GB       1 year          No
# 822         1   512 GB     0 GB            0 GB  No warranty          No
#
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [802 rows x 12 columns]

# %%
df['ssd'].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
ssd_dict={'0 GB':0, '512 GB':512,'256 GB':256, '128 GB':128, '1024 GB':1024, '2048 GB':2048,
       '3072 GB':3072}

# %%
df['ssd']=df['ssd'].map(ssd_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd      hdd graphic_card_gb     warranty Touchscreen   Price
# 0           1     0  1024 GB            0 GB  No warranty          No   34649
# 1           1     0  1024 GB            0 GB  No warranty          No   38999
# 2           1     0  1024 GB            0 GB  No warranty          No   39999
# 3           1   512     0 GB            2 GB  No warranty          No   69990
# 4           1     0   512 GB            0 GB  No warranty          No   26990
# ..        ...   ...      ...             ...          ...         ...     ...
# 818         1  1024     0 GB            0 GB       1 year          No  135990
# 819         1  1024     0 GB            0 GB       1 year          No  144990
# 820         1  1024     0 GB            4 GB       1 year          No  149990
# 821         1  1024     0 GB            4 GB       1 year          No  142990
# 822         1   512     0 GB            0 GB  No warranty          No   57490
#
# [802 rows x 12 columns]

# %%
df['hdd'].unique()
# Out:
# array(['1024 GB', '0 GB', '512 GB', '2048 GB'], dtype=object)

# %%
hdd_dict={'1024 GB':1024, '0 GB':0, '512 GB':512, '2048 GB':2048}

# %%
df['hdd']=df['hdd'].map(hdd_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd   hdd graphic_card_gb     warranty Touchscreen   Price
# 0           1     0  1024            0 GB  No warranty          No   34649
# 1           1     0  1024            0 GB  No warranty          No   38999
# 2           1     0  1024            0 GB  No warranty          No   39999
# 3           1   512     0            2 GB  No warranty          No   69990
# 4           1     0   512            0 GB  No warranty          No   26990
# ..        ...   ...   ...             ...          ...         ...     ...
# 818         1  1024     0            0 GB       1 year          No  135990
# 819         1  1024     0            0 GB       1 year          No  144990
# 820         1  1024     0            4 GB       1 year          No  149990
# 821         1  1024     0            4 GB       1 year          No  142990
# 822         1   512     0            0 GB  No warranty          No   57490
#
# [802 rows x 12 columns]

# %%
df['graphic_card_gb'].unique()
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
graphic_card_dict={'0 GB':0, '2 GB':2, '4 GB':4, '6 GB':6, '8 GB':8}

# %%
df['graphic_card_gb']=df['graphic_card_gb'].map(graphic_card_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd   hdd  graphic_card_gb     warranty Touchscreen   Price
# 0           1     0  1024                0  No warranty          No   34649
# 1           1     0  1024                0  No warranty          No   38999
# 2           1     0  1024                0  No warranty          No   39999
# 3           1   512     0                2  No warranty          No   69990
# 4           1     0   512                0  No warranty          No   26990
# ..        ...   ...   ...              ...          ...         ...     ...
# 818         1  1024     0                0       1 year          No  135990
# 819         1  1024     0                0       1 year          No  144990
# 820         1  1024     0                4       1 year          No  149990
# 821         1  1024     0                4       1 year          No  142990
# 822         1   512     0                0  No warranty          No   57490
#
# [802 rows x 12 columns]

# %%
df['warranty'].unique()
# Out:
# array(['No warranty', '1 year', '2 years', '3 years'], dtype=object)

# %%
warranty_dict={'No warranty':1, '1 year':2, '2 years':3, '3 years':4}

# %%
df['warranty']=df['warranty'].map(warranty_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd   hdd  graphic_card_gb  warranty Touchscreen   Price
# 0           1     0  1024                0         1          No   34649
# 1           1     0  1024                0         1          No   38999
# 2           1     0  1024                0         1          No   39999
# 3           1   512     0                2         1          No   69990
# 4           1     0   512                0         1          No   26990
# ..        ...   ...   ...              ...       ...         ...     ...
# 818         1  1024     0                0         2          No  135990
# 819         1  1024     0                0         2          No  144990
# 820         1  1024     0                4         2          No  149990
# 821         1  1024     0                4         2          No  142990
# 822         1   512     0                0         1          No   57490
#
# [802 rows x 12 columns]

# %%
df['Touchscreen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
touchscreen_dict={'No':1, 'Yes':2}

# %%
df['Touchscreen']=df['Touchscreen'].map(touchscreen_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd   hdd  graphic_card_gb  warranty  Touchscreen   Price
# 0           1     0  1024                0         1            1   34649
# 1           1     0  1024                0         1            1   38999
# 2           1     0  1024                0         1            1   39999
# 3           1   512     0                2         1            1   69990
# 4           1     0   512                0         1            1   26990
# ..        ...   ...   ...              ...       ...          ...     ...
# 818         1  1024     0                0         2            1  135990
# 819         1  1024     0                0         2            1  144990
# 820         1  1024     0                4         2            1  149990
# 821         1  1024     0                4         2            1  142990
# 822         1   512     0                0         1            1   57490
#
# [802 rows x 12 columns]

# %%
x=df.drop('Price', axis=1)
y=df['Price']

# %%
x
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd   hdd  graphic_card_gb  warranty  Touchscreen
# 0           1     0  1024                0         1            1
# 1           1     0  1024                0         1            1
# 2           1     0  1024                0         1            1
# 3           1   512     0                2         1            1
# 4           1     0   512                0         1            1
# ..        ...   ...   ...              ...       ...          ...
# 818         1  1024     0                0         2            1
# 819         1  1024     0                0         2            1
# 820         1  1024     0                4         2            1
# 821         1  1024     0                4         2            1
# 822         1   512     0                0         1            1
#
# [802 rows x 11 columns]

# %%
y
# Out:
# 0       34649
# 1       38999
# 2       39999
# 3       69990
# 4       26990
#         ...
# 818    135990
# 819    144990
# 820    149990
# 821    142990
# 822     57490
# Name: Price, Length: 802, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train, y_test=train_test_split(x,y,random_state=42, test_size=0.4 )

# %%
x_train
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 780      3                2              10                2       4
# 261      1                1               2                1       8
# 366      2                1               2                3       8
# 488      2                1               5                1       8
# 16       5                1               2                3       8
# ..     ...              ...             ...              ...     ...
# 73       2                1               1                1       4
# 108      6                1               1                3       8
# 275      2                1               2                1       8
# 445      1                1               2                3       8
# 104      1                1               1                3       8
#
#      ram_type   ssd   hdd  graphic_card_gb  warranty  Touchscreen
# 780         1  1024     0                4         2            1
# 261         1   512     0                4         2            1
# 366         1   512     0                0         2            2
# 488         1   512     0                4         2            1
# 16          1   256     0                0         2            1
# ..        ...   ...   ...              ...       ...          ...
# 73          1   256     0                0         1            1
# 108         1   512     0                0         2            2
# 275         1   512     0                2         2            1
# 445         1   256  1024                0         2            1
# 104         1   512     0                0         2            1
#
# [481 rows x 11 columns]

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 196      3                1               2                2       8
# 299      1                1               2                3       8
# 171      6                1               1                1       8
# 537      5                1               5                1      16
# 551      7                1               5                3      16
# ..     ...              ...             ...              ...     ...
# 181      6                1               1                3       4
# 548      5                1               5                3      16
# 557      1                1               5                1      16
# 180      1                1               1                1       4
# 665      6                2               4                2       8
#
#      ram_type   ssd   hdd  graphic_card_gb  warranty  Touchscreen
# 196         4     0   512                4         1            1
# 299         3   512     0                0         2            1
# 171         1   256  1024                0         2            1
# 537         1  1024     0                6         2            1
# 551         1  1024     0                8         3            1
# ..        ...   ...   ...              ...       ...          ...
# 181         1   256  1024                0         2            1
# 548         1  1024     0                4         1            1
# 557         1  1024     0                8         1            1
# 180         1   256  1024                0         1            1
# 665         1   256     0                0         2            1
#
# [321 rows x 11 columns]

# %%
y_train
# Out:
# 780    99990
# 261    63990
# 366    82990
# 488    68990
# 16     65390
#        ...
# 73     41990
# 108    60790
# 275    57500
# 445    52990
# 104    44990
# Name: Price, Length: 481, dtype: int64

# %%
y_test
# Out:
# 196     50990
# 299     72990
# 171     41490
# 537    144690
# 551    129990
#         ...
# 181     43990
# 548    121990
# 557    234990
# 180     40990
# 665     44490
# Name: Price, Length: 321, dtype: int64

# %%
x_test.shape,y_test.shape,x_train.shape,y_train.shape
# Out:
# ((321, 11), (321,), (481, 11), (481,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%