# %%
import pandas as pd

# %%
df=pd.read_csv('Used_Bikes.csv')

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail(8)
# Out:
#                        bike_name    price         city  kms_driven  \
# 32640     Hero Passion Pro 100cc  32000.0        Delhi     12000.0
# 32641        Bajaj Avenger 220cc  41000.0        Delhi     20245.0
# 32642         Hero Passion 100cc  15000.0  Perumbavoor     35000.0
# 32643     Hero Passion Pro 100cc  39000.0        Delhi     22000.0
# 32644       TVS Apache RTR 180cc  30000.0       Karnal      6639.0
# 32645   Bajaj Avenger Street 220  60000.0        Delhi     20373.0
# 32646  Hero Super Splendor 125cc  15600.0       Jaipur     84186.0
# 32647         Bajaj Pulsar 150cc  22000.0         Pune     60857.0
#
#               owner   age  power  brand
# 32640   First Owner   6.0  100.0   Hero
# 32641  Second Owner  11.0  220.0  Bajaj
# 32642  Second Owner  19.0  100.0   Hero
# 32643   First Owner   4.0  100.0   Hero
# 32644   First Owner   9.0  180.0    TVS
# 32645   First Owner   6.0  220.0  Bajaj
# 32646   First Owner  16.0  125.0   Hero
# ...

# %%
df.head(6)
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                      Yamaha FZs 150cc   53499.0      Delhi     25000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha
# 5  First Owner  6.0  150.0         Yamaha

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#               price     kms_driven           age         power
# count  3.264800e+04   32648.000000  32648.000000  32648.000000
# mean   6.829542e+04   26344.625184      8.048211    213.511302
# std    9.071860e+04   22208.527695      4.031700    134.428868
# min    4.400000e+03       1.000000      1.000000    100.000000
# 25%    2.500000e+04   12000.000000      5.000000    150.000000
# 50%    4.300000e+04   20373.000000      7.000000    150.000000
# 75%    8.000000e+04   35000.000000     10.000000    220.000000
# max    1.900000e+06  750000.000000     63.000000   1800.000000

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.isnull()
# Out:
#        bike_name  price   city  kms_driven  owner    age  power  brand
# 0          False  False  False       False  False  False  False  False
# 1          False  False  False       False  False  False  False  False
# 2          False  False  False       False  False  False  False  False
# 3          False  False  False       False  False  False  False  False
# 4          False  False  False       False  False  False  False  False
# ...          ...    ...    ...         ...    ...    ...    ...    ...
# 32643      False  False  False       False  False  False  False  False
# 32644      False  False  False       False  False  False  False  False
# 32645      False  False  False       False  False  False  False  False
# 32646      False  False  False       False  False  False  False  False
# 32647      False  False  False       False  False  False  False  False
#
# [32648 rows x 8 columns]

# %%
df.drop_duplicates(inplace = True)  #INPLACE == 'True'

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dropna()         #remove null values from data set
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.drop(['bike_name','city'],axis=1,inplace=True)

# %%
df
# Out:
#          price  kms_driven        owner  age  power            brand
# 0      35000.0     17654.0  First Owner  3.0  110.0              TVS
# 1     119900.0     11000.0  First Owner  4.0  350.0    Royal Enfield
# 2     600000.0       110.0  First Owner  8.0  675.0          Triumph
# 3      65000.0     16329.0  First Owner  4.0  180.0              TVS
# 4      80000.0     10000.0  First Owner  3.0  150.0           Yamaha
# ...        ...         ...          ...  ...    ...              ...
# 9362   25000.0     48587.0  First Owner  8.0  150.0             Hero
# 9369   35000.0     60000.0  First Owner  9.0  220.0            Bajaj
# 9370  450000.0      3430.0  First Owner  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0  First Owner  4.0  400.0            Bajaj
# 9372   80000.0      7127.0  First Owner  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
df.dtypes
# Out:
# price         float64
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth Owner Or More'], dtype=object)

# %%
owner_dict={'First Owner':1,'Second Owner':2,'Third Owner':3,'Fourth Owner Or More':4}

# %%
df['owner']=df['owner'].map(owner_dict)

# %%
df
# Out:
#          price  kms_driven  owner  age  power            brand
# 0      35000.0     17654.0      1  3.0  110.0              TVS
# 1     119900.0     11000.0      1  4.0  350.0    Royal Enfield
# 2     600000.0       110.0      1  8.0  675.0          Triumph
# 3      65000.0     16329.0      1  4.0  180.0              TVS
# 4      80000.0     10000.0      1  3.0  150.0           Yamaha
# ...        ...         ...    ...  ...    ...              ...
# 9362   25000.0     48587.0      1  8.0  150.0             Hero
# 9369   35000.0     60000.0      1  9.0  220.0            Bajaj
# 9370  450000.0      3430.0      1  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0      1  4.0  400.0            Bajaj
# 9372   80000.0      7127.0      1  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
cat_col=df.select_dtypes(include='object')

# %%
cat_col
# Out:
#                 brand
# 0                 TVS
# 1       Royal Enfield
# 2             Triumph
# 3                 TVS
# 4              Yamaha
# ...               ...
# 9362             Hero
# 9369            Bajaj
# 9370  Harley-Davidson
# 9371            Bajaj
# 9372            Bajaj
#
# [7324 rows x 1 columns]

# %%
num_col=df.select_dtypes(exclude='object')

# %%
num_col
# Out:
#          price  kms_driven  owner  age  power
# 0      35000.0     17654.0      1  3.0  110.0
# 1     119900.0     11000.0      1  4.0  350.0
# 2     600000.0       110.0      1  8.0  675.0
# 3      65000.0     16329.0      1  4.0  180.0
# 4      80000.0     10000.0      1  3.0  150.0
# ...        ...         ...    ...  ...    ...
# 9362   25000.0     48587.0      1  8.0  150.0
# 9369   35000.0     60000.0      1  9.0  220.0
# 9370  450000.0      3430.0      1  4.0  750.0
# 9371  139000.0     21300.0      1  4.0  400.0
# 9372   80000.0      7127.0      1  5.0  220.0
#
# [7324 rows x 5 columns]

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
brand_dict={'TVS':1, 'Royal Enfield':2, 'Triumph':3, 'Yamaha':4, 'Honda':5, 'Hero':6,
       'Bajaj':7, 'Suzuki':8, 'Benelli':9, 'KTM':10, 'Mahindra':11, 'Kawasaki':12,
       'Ducati':13, 'Hyosung':14, 'Harley-Davidson':15, 'Jawa':16, 'BMW':17, 'Indian':18,
       'Rajdoot':19, 'LML':20, 'Yezdi':21, 'MV':22, 'Ideal':23}

# %%
# df['brand']=df['brand'].map(brand_dict)

# %%
df
# Out:
#          price  kms_driven  owner  age  power            brand
# 0      35000.0     17654.0      1  3.0  110.0              TVS
# 1     119900.0     11000.0      1  4.0  350.0    Royal Enfield
# 2     600000.0       110.0      1  8.0  675.0          Triumph
# 3      65000.0     16329.0      1  4.0  180.0              TVS
# 4      80000.0     10000.0      1  3.0  150.0           Yamaha
# ...        ...         ...    ...  ...    ...              ...
# 9362   25000.0     48587.0      1  8.0  150.0             Hero
# 9369   35000.0     60000.0      1  9.0  220.0            Bajaj
# 9370  450000.0      3430.0      1  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0      1  4.0  400.0            Bajaj
# 9372   80000.0      7127.0      1  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
df.to_csv
# Out:
# <bound method NDFrame.to_csv of          price  kms_driven  owner  age  power            brand
# 0      35000.0     17654.0      1  3.0  110.0              TVS
# 1     119900.0     11000.0      1  4.0  350.0    Royal Enfield
# 2     600000.0       110.0      1  8.0  675.0          Triumph
# 3      65000.0     16329.0      1  4.0  180.0              TVS
# 4      80000.0     10000.0      1  3.0  150.0           Yamaha
# ...        ...         ...    ...  ...    ...              ...
# 9362   25000.0     48587.0      1  8.0  150.0             Hero
# 9369   35000.0     60000.0      1  9.0  220.0            Bajaj
# 9370  450000.0      3430.0      1  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0      1  4.0  400.0            Bajaj
# 9372   80000.0      7127.0      1  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]>

# %% [markdown]
# machine learning

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
x
# Out:
#       kms_driven  owner  age  power            brand
# 0        17654.0      1  3.0  110.0              TVS
# 1        11000.0      1  4.0  350.0    Royal Enfield
# 2          110.0      1  8.0  675.0          Triumph
# 3        16329.0      1  4.0  180.0              TVS
# 4        10000.0      1  3.0  150.0           Yamaha
# ...          ...    ...  ...    ...              ...
# 9362     48587.0      1  8.0  150.0             Hero
# 9369     60000.0      1  9.0  220.0            Bajaj
# 9370      3430.0      1  4.0  750.0  Harley-Davidson
# 9371     21300.0      1  4.0  400.0            Bajaj
# 9372      7127.0      1  5.0  220.0            Bajaj
#
# [7324 rows x 5 columns]

# %%
brand_dict={'TVS':1, 'Royal Enfield':2, 'Triumph':3, 'Yamaha':4, 'Honda':5, 'Hero':6,
       'Bajaj':7, 'Suzuki':8, 'Benelli':9, 'KTM':10, 'Mahindra':11, 'Kawasaki':12,
       'Ducati':13, 'Hyosung':14, 'Harley-Davidson':15, 'Jawa':16, 'BMW':17, 'Indian':18,
       'Rajdoot':19, 'LML':20, 'Yezdi':21, 'MV':22, 'Ideal':23}

# %%
x['brand']=x['brand'].map(brand_dict)

# %%
x
# Out:
#       kms_driven  owner  age  power  brand
# 0        17654.0      1  3.0  110.0      1
# 1        11000.0      1  4.0  350.0      2
# 2          110.0      1  8.0  675.0      3
# 3        16329.0      1  4.0  180.0      1
# 4        10000.0      1  3.0  150.0      4
# ...          ...    ...  ...    ...    ...
# 9362     48587.0      1  8.0  150.0      6
# 9369     60000.0      1  9.0  220.0      7
# 9370      3430.0      1  4.0  750.0     15
# 9371     21300.0      1  4.0  400.0      7
# 9372      7127.0      1  5.0  220.0      7
#
# [7324 rows x 5 columns]

# %%
y
# Out:
# 0        35000.0
# 1       119900.0
# 2       600000.0
# 3        65000.0
# 4        80000.0
#           ...
# 9362     25000.0
# 9369     35000.0
# 9370    450000.0
# 9371    139000.0
# 9372     80000.0
# Name: price, Length: 7324, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y , random_state=42, test_size=0.2)

# %%
x_train
# Out:
#       kms_driven  owner   age  power  brand
# 5789     68857.0      1  15.0  110.0      1
# 3451      5740.0      1   6.0  500.0      2
# 735      28329.0      1   6.0  110.0      6
# 7533     42966.0      1   7.0  150.0      4
# 8461      8000.0      1   5.0  500.0      2
# ...          ...    ...   ...    ...    ...
# 6522     56000.0      1   9.0  200.0      7
# 6583     22493.0      1   5.0  500.0      2
# 6856     17477.0      1   5.0  150.0      7
# 1028     14836.0      1   8.0  150.0      4
# 9250      8000.0      1  10.0  250.0      5
#
# [5859 rows x 5 columns]

# %%
y_train
# Out:
# 5789     18000.0
# 3451    140000.0
# 735      32000.0
# 7533     40000.0
# 8461    160000.0
#           ...
# 6522     48928.0
# 6583    114000.0
# 6856     41000.0
# 1028     40000.0
# 9250     80000.0
# Name: price, Length: 5859, dtype: float64

# %%
x_test
# Out:
#       kms_driven  owner   age  power  brand
# 4909     22500.0      1   6.0  350.0      2
# 1942      3198.0      1   5.0  500.0      2
# 5763     15000.0      1   6.0  220.0      7
# 4800     27000.0      1  12.0  150.0      4
# 7614     16764.0      1   9.0  100.0      6
# ...          ...    ...   ...    ...    ...
# 5653     16523.0      1   5.0  750.0     15
# 609       2881.0      1   7.0  250.0     14
# 4211     23833.0      1   4.0  150.0      8
# 6379      9282.0      1   7.0  500.0      2
# 647       2980.0      1   6.0  160.0      1
#
# [1465 rows x 5 columns]

# %%
y_test
# Out:
# 4909     88400.0
# 1942    102850.0
# 5763     67000.0
# 4800     30000.0
# 7614     20000.0
#           ...
# 5653    395000.0
# 609     140000.0
# 4211     54500.0
# 6379    114000.0
# 647      36000.0
# Name: price, Length: 1465, dtype: float64

# %%
x_test.shape, y_test.shape, x_train.shape, y_train.shape
# Out:
# ((1465, 5), (1465,), (5859, 5), (5859,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)
# Out:
# 0.7586900869386211

# %%
lr.score(x_train, y_train)
# Out:
# 0.7053826605671762

# %%
pred= lr.predict(x_test)

# %%
pred
# Out:
# array([125382.54523531, 216422.20333617,  96966.48595241, ...,
#         72233.83615101, 208856.67620686,   9305.60087569], shape=(1465,))

# %%
df["brand"]      #to enter in a column
# Out:
# 0                   TVS
# 1         Royal Enfield
# 2               Triumph
# 3                   TVS
# 4                Yamaha
#              ...
# 9362               Hero
# 9369              Bajaj
# 9370    Harley-Davidson
# 9371              Bajaj
# 9372              Bajaj
# Name: brand, Length: 7324, dtype: object

# %%
df["brand"].unique()  #give the unique values
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df["brand"].nunique()    #count the number of unique values
# Out:
# 23

# %%
df["bike_name"].value_counts()   #tells about the quantity according to brAnd
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\91746\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bike_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[159], line 1
# ...

# %% [markdown]
# bike
# tvs
# kms 50000
# price 50000
# owner 1st

# %%
df["brand"].unique()

# %%
tvs_df=df[df["brand"] == 'TVS']
tvs_df

# %%
tvs_First_df=tvs_df[tvs_df["owner"]=='First Owner']

# %%
tvs_df=df[df['brand']=='TVS']

# %%
first_tvs_df=tvs_df[tvs_df['owner']=='First Owner']

# %%
first_tvs_df[first_tvs_df['kms_driven']<=50000]

# %% [markdown]
# brand =hero
# price <=70k
# age= <=2
# first owner

# %%
hero_df=df[df['brand']=='Hero']
first_hero_df=hero_df[hero_df['owner']=='First Owner']
under70k_first_hero_df=first_hero_df[first_hero_df['price']<=70000]
power150_under70k_first_hero_df=under70k_first_hero_df[under70k_first_hero_df['power']==110]
age2_power150_under70k_first_hero_df=power150_under70k_first_hero_df[power150_under70k_first_hero_df['age']<=2]
age2_power150_under70k_first_hero_df
