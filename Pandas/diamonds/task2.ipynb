# %%
import pandas as pd

# %%
df=pd.read_csv("diamonds.csv")

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [50000 rows x 10 columns]

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Length: 50000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(126)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dropna()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
cut_dict={'Ideal':1, 'Premium':2, 'Good':3, 'Very Good':4, 'Fair':5}

# %%
df['cut']=df['cut'].map(cut_dict)

# %%
df['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
color_dict={'E':1, 'I':2, 'J':3, 'H':4, 'F':5, 'G':6, 'D':7}

# %%
df['color']=df['color'].map(color_dict)

# %%
df['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
clarity_dict={'SI2':1, 'SI1':2, 'VS1':3, 'VS2':4, 'VVS2':5, 'VVS1':6, 'I1':7, 'IF':8}

# %%
df['clarity']=df['clarity'].map(clarity_dict)

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    1      1        1   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    2      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    3      1        3   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    2      2        4   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    3      3        1   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 49995   0.72    1      7        2   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72    3      7        2   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70    4      7        2   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    2      4        1   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75    1      7        1   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
x=df.drop('price', axis=1)
y=df['price']

# %%
x
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 0       0.23    1      1        1   61.5   55.0  3.95  3.98  2.43
# 1       0.21    2      1        2   59.8   61.0  3.89  3.84  2.31
# 2       0.23    3      1        3   56.9   65.0  4.05  4.07  2.31
# 3       0.29    2      2        4   62.4   58.0  4.20  4.23  2.63
# 4       0.31    3      3        1   63.3   58.0  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...
# 49995   0.72    1      7        2   60.8   57.0  5.75  5.76  3.50
# 49996   0.72    3      7        2   63.1   55.0  5.69  5.75  3.61
# 49997   0.70    4      7        2   62.8   60.0  5.66  5.68  3.56
# 49998   0.86    2      4        1   61.0   58.0  6.15  6.12  3.74
# 49999   0.75    1      7        1   62.2   55.0  5.83  5.87  3.64
#
# [49874 rows x 9 columns]

# %%
y
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 49995    2757
# 49996    2757
# 49997    2757
# 49998    2757
# 49999    2757
# Name: price, Length: 49874, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train , y_test=train_test_split(x,y, random_state=42,test_size=0.2)

# %%
x_train
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 19023   1.28    2      6        4   61.6   58.0  7.02  6.98  4.31
# 29565   0.30    3      4        5   63.7   55.0  4.27  4.24  2.71
# 45969   0.32    4      5        1   63.1   56.0  4.38  4.34  2.75
# 42182   0.56    4      6        3   60.2   56.0  5.35  5.37  3.23
# 25633   2.38    2      3        4   62.1   58.0  8.54  8.49  5.29
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...
# 11309   1.01    2      6        2   60.0   58.0  6.54  6.50  3.91
# 44855   0.71    4      4        1   63.7   56.0  5.62  5.65  3.59
# 38270   0.56    1      2        2   61.8   54.0  5.28  5.31  3.27
# 860     0.73    1      1        2   61.4   56.0  5.79  5.81  3.56
# 15828   1.07    3      5        4   57.6   60.0  6.83  6.79  3.92
#
# [39899 rows x 9 columns]

# %%
x_test
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 19256   1.20    1      6        3   61.7   55.0  6.92  6.88  4.26
# 16820   1.20    4      6        4   63.1   57.0  6.69  6.74  4.24
# 26664   0.31    2      1        4   60.3   58.0  4.37  4.42  2.65
# 27304   0.40    1      6        2   61.3   56.0  4.73  4.76  2.91
# 821     1.00    5      2        2   66.3   61.0  6.08  6.03  4.01
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...
# 16982   0.37    2      5        2   61.6   59.0  4.62  4.67  2.86
# 34272   0.25    4      5        3   60.7   57.0  4.06  4.09  2.47
# 30016   0.32    1      1        5   62.0   54.0  4.41  4.43  2.74
# 41972   0.51    4      1        4   63.3   57.0  5.12  5.05  3.22
# 43039   0.54    1      5        3   61.1   57.0  5.28  5.30  3.23
#
# [9975 rows x 9 columns]

# %%
y_train
# Out:
# 19023     8874
# 29565      776
# 45969      540
# 42182     1686
# 25633    18559
#          ...
# 11309     5204
# 44855     1972
# 38270     1212
# 860       2886
# 15828     6828
# Name: price, Length: 39899, dtype: int64

# %%
y_test
# Out:
# 19256    9038
# 16820    7371
# 26664     680
# 27304     701
# 821      2875
#          ...
# 16982     616
# 34272     480
# 30016     790
# 41972    1662
# 43039    1774
# Name: price, Length: 9975, dtype: int64

# %%
x_test.shape,y_test.shape, x_train.shape, y_train.shape
# Out:
# ((9975, 9), (9975,), (39899, 9), (39899,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.8744139192712975

# %%
lr.score(x_test,y_test)
# Out:
# 0.8683524007358765

# %%
pred=lr.predict(x_test)

# %%
pred
# Out:
# array([7290.7719156 , 7193.84586666,  350.40160048, ...,  698.34639334,
#        1065.39706938, 1947.69705737], shape=(9975,))
